# %% [markdown]
# <a href="https://colab.research.google.com/github/karthik14-03/AICTE-Water-resource-management-project/blob/main/python_proects.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Project 1: To-Do List

# %%
import json
import os

FILE_NAME = "tasks.json"

def load_task():
    if os.path.exists(FILE_NAME):
        with open(FILE_NAME, "r") as file:
            tasks = json.load(file)
    else:
        tasks = []
    return tasks

def save_tasks(tasks):
    with open(FILE_NAME, "w") as file:
        json.dump(tasks, file, indent=4)

def show_tasks(tasks):
    if not tasks:
        print("No tasks found.")
    else:
        for i, task in enumerate(tasks, start=1):
            status = "DONE" if task["completed"] else "NOT YET DONE"
            print(f"{i}. {task['title']} [{status}]")

def add_tasks(tasks):
    title = input("Enter task title: ")
    tasks.append({"title": title, "completed": False})
    save_tasks(tasks)
    print("Task added successfully!")

def mark_done(tasks):
    show_tasks(tasks)
    try:
        num = int(input("Enter task number to mark as done: "))
        if 1 <= num <= len(tasks):
            tasks[num - 1]["completed"] = True
            save_tasks(tasks)
            print("Task marked as done.")
        else:
            print("Invalid number.")
    except ValueError:
        print("Please enter a valid number.")

def delete_task(tasks):
    show_tasks(tasks)
    try:
        num = int(input("Enter task number to delete: "))
        if 1 <= num <= len(tasks):
            del tasks[num - 1]
            save_tasks(tasks)
            print("Task deleted successfully!")
        else:
            print("Invalid number.")
    except ValueError:
        print("Please enter a valid number.")

# %%
tasks = load_task()

# %%
show_tasks(tasks)
# Out:
# 1. homework [DONE]
# 2. intern [NOT YET DONE]
# 3. happy [NOT YET DONE]

# %%
add_tasks(tasks)
# Out:
# Enter task title: happy
# Task added successfully!

# %%
mark_done(tasks)
# Out:
# 1. homework [DONE]
# 2. intern [NOT YET DONE]
# 3. happy [NOT YET DONE]
# Enter task number to mark as done: 3
# Task marked as done.

# %%
delete_task(tasks)
# Out:
# 1. homework [DONE]
# 2. intern [NOT YET DONE]
# 3. happy [DONE]
# Enter task number to delete: 0
# Invalid number.

# %%
tasks = load_task()
print(tasks)
# Out:
# [{'title': 'homework', 'completed': True}, {'title': 'intern', 'completed': False}, {'title': 'happy', 'completed': True}]
